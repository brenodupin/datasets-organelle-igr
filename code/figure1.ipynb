# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.gridspec import GridSpec
from pathlib import Path
import polars as pl
from statistics import mean


def parse_estimate(ls):
    value = float(ls.split("= ")[1].split(" ", 1)[0].strip())
    lo = float(ls.split("(")[1].split("-")[0].strip())
    hi = float(ls.split("-")[1].split(")")[0].strip())
    return value, lo, hi


def parse_both_fold_block(text):
    lines = text.splitlines()
    in_both_block = False
    conv = div = None

    for line in lines:
        ls = line.strip()
        if ls == "[both]":
            in_both_block = True
            continue
        if in_both_block:
            if ls.startswith("polarity_3binconv"):
                parts = ls.split()
                conv = tuple(float(x) for x in parts[1:4])
            elif ls.startswith("polarity_3bindiv"):
                parts = ls.split()
                div = tuple(float(x) for x in parts[1:4])
                break  # both rows found, stop scanning

    if conv is None or div is None:
        raise ValueError("Could not find '[both]' polarity contrast block")

    return conv, div


def _mt(text, bold):
    body = text.replace(",", "{,}")
    cmd = r"\mathbf" if bold else r"\mathrm"
    return f"${cmd}{{{body}}}$"


def _tick_label(g, an=None, igr=None, bold_groups=None, only_group=False):
    name = g.replace("_mit", "").replace("_plt", "").replace("_", " ").capitalize()
    if only_group:
        return f"{name}"

    bold = g in bold_groups
    return f"{name}\n" + _mt(f"(an={an:,}", bold) + "\n" + _mt(f"igr={igr:,})", bold)

# %%
# Assuming either all *_compressed.tar.zst files or all_groups_lean.tar.zst file is/are decompressed
CWD = Path().resolve()
BASE = CWD.parent

print(f"Current working directory (where figure will be saved): {CWD}")
print(f"Folder where groups (data) folder should be: {BASE}")

# %%
groups = [
    "fungi_mit",
    "metazoans_mit",
    "plants_mit",
    "plants_plt",
    "protists_mit",
    "protists_plt",
    "green_algae_mit",
    "green_algae_plt",
]

violin_order = [
    # mitochondria
    "fungi_mit",
    "metazoans_mit",
    "plants_mit",
    "protists_mit",
    "green_algae_mit",
    # plastids
    "plants_plt",
    "protists_plt",
    "green_algae_plt",
]
polarity_2bin = {
    "conv": "opposite",
    "div": "opposite",
    "same": "same",
}

group_label1 = {
    "fungi_mit": "Fungi",
    "metazoans_mit": "Metazoans",
    "plants_mit": "Plants",
    "protists_mit": "Protists",
    "green_algae_mit": "Green algae",
    "plants_plt": "Plants ",
    "protists_plt": "Protists ",
    "green_algae_plt": "Green algae ",
}

organelle_dict = {
    "Fungi": "Mitochondria",
    "Metazoans": "Mitochondria",
    "Plants": "Mitochondria",
    "Protists": "Mitochondria",
    "Green algae": "Mitochondria",
    "Plants ": "Plastid",
    "Protists ": "Plastid",
    "Green algae ": "Plastid",
}

boxplot_titles = {
    "fungi_mit": "Fungi (mitochondria)",
    "metazoans_mit": "Metazoans (mitochondria)",
    "plants_mit": "Plants (mitochondria)",
    "protists_mit": "Protists (mitochondria)",
    "green_algae_mit": "Green algae (mitochondria)",
    "plants_plt": "Plants (plastids)",
    "protists_plt": "Protists (plastids)",
    "green_algae_plt": "Green algae (plastids)",
}
COLOR_SAME = "#D55E00"  # vermillion
COLOR_OPPO = "#56B4E9"  # sky blue
VIOLIN_COLOR = "#009E73"  # teal green

BOLD_GROUPS = {"plants_plt", "metazoans_mit"}

GROUP_ORDER = [
    "Fungi",
    "Metazoans",
    "Plants",
    "Protists",
    "Green algae",
    "Plants ",
    "Protists ",
    "Green algae ",
]

COLOR_CONV = "#56B4E9"  # sky blue
COLOR_DIV = "#03045E"  # deep navy

# %%
# Load and summarize all groups
group_data = {}
for g in groups:
    df = pl.read_csv(
        BASE / g / "brms_type_length" / f"filtered_3bin.tsv", separator="\t"
    ).select(["AN", "polarity_3bin", "igr_len"])

    df = df.with_columns(
        pl.col("polarity_3bin").replace_strict(polarity_2bin).alias("polarity_2bin")
    )

    # Per-genome medians by bin
    med = df.group_by(["AN", "polarity_2bin"]).agg(
        pl.col("igr_len").log10().median().alias("median_log10_length"),
    )

    wide = med.pivot(index="AN", on="polarity_2bin", values="median_log10_length")
    delta = wide["opposite"].to_numpy() - wide["same"].to_numpy()

    group_data[g] = {
        "group": g,
        "wide": wide,
        "wide_paired": wide,
        "delta_med_log10": delta,
        "an": len(delta),
        "igr": df.height,
    }

delta_violin_data = [group_data[g]["delta_med_log10"] for g in violin_order]
an_by_group = [group_data[g]["an"] for g in violin_order]
igr_by_group = [group_data[g]["igr"] for g in violin_order]

# %%
rows = []
legend_data = {}

for g in groups:
    igr = pl.read_csv(
        BASE / g / "brms_type_length" / f"filtered_3bin.tsv", separator="\t"
    )
    brm_result = BASE / g / "brms_type_length" / "brms_result.txt"  # <-- CONFIRM PATH
    legend_data[group_label1[g]] = {
        "an": igr.select(pl.col("AN")).n_unique(),
        "igr": igr.height,
    }

    text = brm_result.read_text()
    (conv_fold, conv_fold_lo, conv_fold_hi), (div_fold, div_fold_lo, div_fold_hi) = (
        parse_both_fold_block(text)
    )

    label = group_label1.get(g, g)
    organelle = organelle_dict.get(label, "Unknown")
    rows.append(
        {
            "group": label,
            "polarity": "convergent",
            "real_group": g,
            "fold": conv_fold,
            "ci_low": conv_fold_lo,
            "ci_high": conv_fold_hi,
            "organelle": organelle,
        }
    )
    rows.append(
        {
            "group": label,
            "polarity": "divergent",
            "real_group": g,
            "fold": div_fold,
            "ci_low": div_fold_lo,
            "ci_high": div_fold_hi,
            "organelle": organelle,
        }
    )

    print(f"{g}")
    print(f"  Conv Fold(both)={conv_fold:.3f} ({conv_fold_lo:.3f},{conv_fold_hi:.3f})")
    print(f"  Div  Fold(both)={div_fold:.3f} ({div_fold_lo:.3f},{div_fold_hi:.3f})\n")

data = pl.DataFrame(rows)

# %%
# Composite figure layout
width = 15
violin_height = width / 2  # 6.5 for 2:1 ratio
forest_height = violin_height
dpi = 300

fig = plt.figure(figsize=(width, violin_height + forest_height), dpi=dpi)
gs = GridSpec(
    nrows=2,
    ncols=1,
    height_ratios=[violin_height, forest_height],
    hspace=0.12,
    figure=fig,
)

# %%
# ==========
# Panel A: Δ violin plot
# ==========
axA = fig.add_subplot(gs[0, 0])

positions = list(range(1, len(violin_order) + 1))

vp = axA.violinplot(
    delta_violin_data,
    positions=positions,
    widths=0.85,
    showmeans=False,
    showmedians=True,
    showextrema=False,
)
for body in vp["bodies"]:
    body.set_facecolor(VIOLIN_COLOR)
    body.set_alpha(0.5)

axA.boxplot(
    delta_violin_data,
    positions=positions,
    widths=0.25,
    showfliers=False,
    medianprops=dict(linewidth=2, color="black"),
)
axA.axhline(0, linewidth=1, color="black", alpha=0.5, zorder=1)

axA.set_xticks(positions)
axA.set_xticklabels(
    [_tick_label(g, only_group=True) for g in violin_order], rotation=0, fontsize=13
)
axA.tick_params(axis="both", labelsize=13)
axA.set_ylabel(
    r"Within-genome $\Delta$ median $\log_{10}$ IGR length" "\n" r"(opposite $-$ same)",
    fontsize=13,
)
axA.grid(axis="y", alpha=0.2)

axA.axvline(5.5, color="gray", linestyle="--", alpha=0.3, linewidth=1.5)
fig.text(0.125, 0.895, "A", fontsize=16, fontweight="bold", va="top")

# %%
# ==========
# Panel B: fold-change plot (adapted into gridspec)
# ==========
axB = fig.add_subplot(gs[1, 0])

positions = list(range(1, len(GROUP_ORDER) + 1))
x_pos = {g: i for i, g in zip(positions, GROUP_ORDER)}
small_marker = {"Metazoans", "Plants ", "Protists "}

axB.axhline(1.0, linewidth=1, color="black", alpha=0.5, zorder=1)

for row in data.iter_rows(named=True):
    xi = x_pos[row["group"]]
    is_conv = row["polarity"] == "convergent"
    x = xi - 0.15 if is_conv else xi + 0.15
    col = COLOR_CONV if is_conv else COLOR_DIV
    axB.errorbar(
        x,
        row["fold"],
        yerr=[[row["fold"] - row["ci_low"]], [row["ci_high"] - row["fold"]]],
        fmt="o",
        color=col,
        markersize=7 if row["group"] not in small_marker else 3,
        capsize=4,
        capthick=1.5,
        elinewidth=1.5,
        zorder=3,
    )

axB.axvline(5.5, color="gray", linestyle="--", alpha=0.3, linewidth=1.5)
axB.set_xticks(positions)
axB.set_xticklabels(
    [
        _tick_label(g, an, igr, BOLD_GROUPS)
        for g, an, igr in zip(violin_order, an_by_group, igr_by_group)
    ],
    rotation=0,
    fontsize=13,
)
axB.set_xlim(0.5, len(GROUP_ORDER) + 0.5)
axB.set_ylabel(
    "Adjusted fold change in IGR length\n(relative to same-polarity IGRs", fontsize=13
)
axB.grid(axis="y", alpha=0.2)
axB.legend(
    handles=[
        mpatches.Patch(color=COLOR_CONV, label="Convergent"),
        mpatches.Patch(color=COLOR_DIV, label="Divergent"),
    ],
    frameon=False,
    fontsize=11.5,
    loc="upper right",
)

mit_positions = positions[:5]
plt_positions = positions[5:]
for xc, label in [
    (mean(mit_positions), "Mitochondria"),
    (mean(plt_positions), "Plastid"),
]:
    axB.text(
        xc,
        -0.15,
        label,
        ha="center",
        va="top",
        fontweight="bold",
        fontsize=15,
        transform=axB.get_xaxis_transform(),
    )

fig.text(0.125, 0.4880, "B", fontsize=16, fontweight="bold", va="top")

# %%
out_path = CWD / "figure1.png"
fig.savefig(out_path, dpi=300, bbox_inches="tight")
print(f"Saved composite figure to: {out_path}")
