# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from pathlib import Path
import polars as pl
import random
from statistics import mean

# %%
# Assuming either all *_compressed.tar.zst files or all_groups_lean.tar.zst file is/are decompressed
CWD = Path().resolve()
BASE = CWD.parent

print(f"Current working directory (where figure will be saved): {CWD}")
print(f"Folder where groups (data) folder should be: {BASE}")

# %%
groups = [
    "fungi_mit",
    "metazoans_mit",
    "plants_mit",
    "plants_plt",
    "protists_mit",
    "protists_plt",
    "green_algae_mit",
    "green_algae_plt",
]

violin_order = [
    # mitochondria
    "fungi_mit",
    "metazoans_mit",
    "plants_mit",
    "protists_mit",
    "green_algae_mit",
    # plastids
    "plants_plt",
    "protists_plt",
    "green_algae_plt",
]

polarity_map = {
    "++": "same",
    "--": "same",
    "+-": "opposite",
    "-+": "opposite",
}

# Global RNG (reproducible)
SEED = 42
random.seed(SEED)

boxplot_titles = {
    "fungi_mit": "Fungi (mitochondria)",
    "metazoans_mit": "Metazoans (mitochondria)",
    "plants_mit": "Plants (mitochondria)",
    "protists_mit": "Protists (mitochondria)",
    "green_algae_mit": "Green algae (mitochondria)",
    "plants_plt": "Plants (plastids)",
    "protists_plt": "Protists (plastids)",
    "green_algae_plt": "Green algae (plastids)",
}
COLOR_SAME = "#D55E00"  # vermillion
COLOR_OPPO = "#56B4E9"  # sky blue
VIOLIN_COLOR = "#009E73"  # teal green

# %%
# Load and summarize all groups
group_data = {}
for g in groups:
    df = pl.read_csv(BASE / g / "summary_igs_intergenic.tsv", separator="\t").select(
        ["AN", "Polarity", "Length"]
    )

    df = df.with_columns(
        pl.col("Polarity")
        .replace_strict(polarity_map, default=None)
        .alias("polarity_bin")
    )

    # Per-genome medians by bin
    med = df.group_by(["AN", "polarity_bin"]).agg(
        pl.col("Length").log10().median().alias("median_log10_length"),
    )

    wide = med.pivot(index="AN", on="polarity_bin", values="median_log10_length")
    delta = wide["opposite"].to_numpy() - wide["same"].to_numpy()

    group_data[g] = {
        "group": g,
        "wide": wide,
        "wide_paired": wide,
        "delta_med_log10": delta,
        "n": len(delta),
    }

delta_violin_data = [group_data[g]["delta_med_log10"] for g in violin_order]
n_by_group = [group_data[g]["n"] for g in violin_order]

# %%
# Composite figure layout
width = 13
violin_height = width / 2  # 6.5 for 2:1 ratio
boxplot_height = 17  # 4 rows × 4.5 inches each
dpi = 300

fig = plt.figure(figsize=(width, violin_height + boxplot_height), dpi=dpi)
gs = GridSpec(
    nrows=2,
    ncols=1,
    height_ratios=[violin_height, boxplot_height],
    hspace=0.2,
    figure=fig,
)

# %%
# ==========
# Panel A: Δ violin plot
# ==========
axA = fig.add_subplot(gs[0, 0])

positions = list(range(1, len(violin_order) + 1))

vp = axA.violinplot(
    delta_violin_data,
    positions=positions,
    widths=0.85,
    showmeans=False,
    showmedians=True,
    showextrema=False,
)
for body in vp["bodies"]:
    body.set_facecolor(VIOLIN_COLOR)
    body.set_alpha(0.5)

axA.boxplot(
    delta_violin_data,
    positions=positions,
    widths=0.25,
    showfliers=False,
    medianprops=dict(linewidth=2, color="black"),
)
axA.axhline(0, linewidth=1)

axA.set_xticks(positions)
axA.set_xticklabels(
    [
        g.replace("_mit", "").replace("_plt", "").replace("_", " ").capitalize()
        + f"\n(n={n})"
        for g, n in zip(violin_order, n_by_group)
    ],
    rotation=0,
)
axA.tick_params(axis="both", labelsize=13)
axA.set_ylabel(
    r"$\mathrm{median}(\log_{10}(\mathrm{opposite})) - \mathrm{median}(\log_{10}(\mathrm{same}))$",
    fontsize=13,
)
axA.grid(axis="y", alpha=0.2)

axA.text(
    mean(positions[:5]),
    -0.15,
    "Mitochondria",
    ha="center",
    va="top",
    fontweight="bold",
    fontsize=12,
    transform=axA.get_xaxis_transform(),
)
axA.text(
    mean(positions[5:]),
    -0.15,
    "Plastid",
    ha="center",
    va="top",
    fontweight="bold",
    fontsize=12,
    transform=axA.get_xaxis_transform(),
)

axA.axvline(5.5, color="gray", linestyle="--", alpha=0.3, linewidth=1.5)
fig.text(0.125, 0.895, "A", fontsize=16, fontweight="bold", va="top")

# %%
# ==========
# Panel B: 4x2 grid of boxplots
# ==========
subgs = gs[1, 0].subgridspec(4, 2, hspace=0.35, wspace=0.25)

for idx, g in enumerate(groups):
    r = idx // 2
    c = idx % 2
    ax = fig.add_subplot(subgs[r, c])

    wide = group_data[g]["wide"]
    boxplot_data = [wide["same"], wide["opposite"]]

    ax.boxplot(
        boxplot_data,
        tick_labels=["same", "opposite"],
        showfliers=False,
        medianprops=dict(linewidth=2, color="black"),
    )

    for i, (arr, color) in enumerate(
        zip(boxplot_data, [COLOR_SAME, COLOR_OPPO]), start=1
    ):
        if len(arr) == 0:
            continue
        x = [random.gauss(i, 0.06) for _ in arr]
        ax.scatter(x, arr, s=10, alpha=0.35, color=color)

    if wide.shape[0] > 0:
        sampled = wide.sample(n=min(600, wide.shape[0]), seed=SEED)
        for row in sampled.iter_rows(named=True):
            ax.plot(
                [1, 2],
                [row["same"], row["opposite"]],
                alpha=0.12,
                linewidth=0.7,
                zorder=0,
                color="gray",
            )

    ax.set_title(boxplot_titles[g], fontsize=14)
    ax.tick_params(axis="both", labelsize=13)
    ax.set_ylabel(r"$\mathrm{median}(\log_{10}(\mathrm{IGR\ length}))$", fontsize=13)
    ax.set_xlabel(
        "" if r < 3 else "Gene-pair polarity type", fontsize=12, fontweight="bold"
    )

fig.text(0.125, 0.63, "B", fontsize=16, fontweight="bold", va="top")

# %%
out_path = CWD / "figure1.png"
fig.savefig(out_path, dpi=300, bbox_inches="tight")
print(f"Saved composite figure to: {out_path}")
