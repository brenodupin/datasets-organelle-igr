# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.gridspec import GridSpec
from pathlib import Path
import polars as pl
from statistics import mean


def _mt(text, bold):
    body = text.replace(",", "{,}")
    cmd = r"\mathbf" if bold else r"\mathrm"
    return f"${cmd}{{{body}}}$"


def _tick_label(g, an=None, igr=None, bold_groups=None, only_group=False):
    name = g.replace("_mit", "").replace("_plt", "").replace("_", " ").capitalize()
    if only_group:
        return f"{name}"

    bold = g in bold_groups
    if igr > 1e6:
        return (
            f"{name}\n"
            + _mt(f"(AN={an:,}", bold)
            + "\n"
            + _mt(f"IGR≈{igr/1e6:.1f}M)", bold)
        )
    return f"{name}\n" + _mt(f"(AN={an:,}", bold) + "\n" + _mt(f"IGR={igr:,})", bold)


def add_label(label, data):
    return {x: f"{x}{label}" for x in data}

# %%
# Assuming either all *_compressed.tar.zst files or all_groups_lean.tar.zst file is/are decompressed
CWD = Path().resolve()
BASE = CWD.parent

print(f"Current working directory (where figure will be saved): {CWD}")
print(f"Folder where groups (data) folder should be: {BASE}")

# %%
groups = [
    # mitochondria
    "fungi_mit",
    "metazoans_mit",
    "plants_mit",
    "protists_mit",
    "green_algae_mit",
    # plastids
    "plants_plt",
    "protists_plt",
    "green_algae_plt",
]

polarity_2bin = {
    "++": "same",
    "--": "same",
    "+-": "opposite",
    "-+": "opposite",
}

polarity_3bin = {
    "++": "same",
    "--": "same",
    "+-": "conv",
    "-+": "div",
}
label_2bin = set(polarity_2bin.values())
label_3bin = set(polarity_3bin.values())


group_label1 = {
    "fungi_mit": "Fungi",
    "metazoans_mit": "Metazoans",
    "plants_mit": "Plants",
    "protists_mit": "Protists",
    "green_algae_mit": "Green algae",
    "plants_plt": "Plants ",
    "protists_plt": "Protists ",
    "green_algae_plt": "Green algae ",
}

COLOR_SAME = "#D55E00"  # vermillion
VIOLIN_COLOR = "#009E73"  # teal green

BOLD_GROUPS = {"plants_plt", "metazoans_mit"}

COLOR_CONV = "#56B4E9"  # sky blue
COLOR_DIV = "#03045E"  # deep navy

# %%
# Load and summarize all groups
group_data = {}
for g in groups:
    df = pl.read_csv(BASE / g / f"{g}_summary_igr.tsv", separator="\t").select(
        ["AN", "Polarity", "Length"]
    )

    df = df.with_columns(
        pl.col("Polarity").replace_strict(polarity_2bin).alias("polarity_2bin")
    )

    # Per-genome medians by bin
    med = df.group_by(["AN", "polarity_2bin"]).agg(
        pl.col("Length").log10().median().alias("median_log10_length"),
    )

    wide = med.pivot(index="AN", on="polarity_2bin", values="median_log10_length")
    delta = wide["opposite"].to_numpy() - wide["same"].to_numpy()

    group_data[g] = {
        "group": g,
        "wide": wide,
        "wide_paired": wide,
        "delta_med_log10": delta,
        "an": len(delta),
        "igr": df.height,
    }

delta_violin_data = [group_data[g]["delta_med_log10"] for g in groups]
an_by_group = [group_data[g]["an"] for g in groups]
igr_by_group = [group_data[g]["igr"] for g in groups]

# %%
rows_3bin = []

for g in groups:
    print(g)
    tsv = pl.read_csv(BASE / g / f"{g}.tsv", separator="\t")
    igs = pl.read_csv(BASE / g / f"{g}_summary_igr.tsv", separator="\t")

    igs = igs.join(
        tsv.select(["AN", "Genome_length"]),
        on="AN",
        how="left",
        validate="m:1",
    )

    igs = igs.with_columns(
        pl.col("Polarity").replace_strict(polarity_3bin).alias("polarity_3bin")
    )

    med = igs.group_by(["AN", "polarity_3bin"]).agg(
        pl.col("Length").count().alias("count"),
        pl.col("Length").sum().alias("total_bp"),
    )

    wide_counts = med.pivot(values="count", index="AN", on="polarity_3bin")
    wide_counts = wide_counts.rename(add_label("_count", label_3bin))

    wide_totals = med.pivot(values="total_bp", index="AN", on="polarity_3bin")
    wide_totals = wide_totals.rename(add_label("_total", label_3bin))

    igs_sizes = igs.group_by("AN").agg(pl.col("Length").sum().alias("total_igs_size"))

    wide = wide_counts.join(wide_totals, on="AN", how="left", validate="1:1").join(
        igs_sizes, on="AN", how="left", validate="m:1"
    )

    # --- enrichment ratios ---
    sum_total = wide["total_igs_size"].sum()
    sum_counts = (
        wide["conv_count"].sum() + wide["div_count"].sum() + wide["same_count"].sum()
    )

    P_obs_conv = wide["conv_total"].sum() / sum_total
    P_obs_div = wide["div_total"].sum() / sum_total
    P_obs_same = wide["same_total"].sum() / sum_total

    P_exp_conv = wide["conv_count"].sum() / sum_counts
    P_exp_div = wide["div_count"].sum() / sum_counts
    P_exp_same = wide["same_count"].sum() / sum_counts

    E_conv = P_obs_conv / P_exp_conv
    E_div = P_obs_div / P_exp_div
    E_same = P_obs_same / P_exp_same

    rows_3bin.append({"group": g, "E_conv": E_conv, "E_div": E_div, "E_same": E_same})

    print(
        f"Observed pct (by length): Convergent: {P_obs_conv:.4f}, Divergent: {P_obs_div:.4f}, Same: {P_obs_same:.4f}"
    )
    print(
        f"Expected pct (by count):  Convergent: {P_exp_conv:.4f}, Divergent: {P_exp_div:.4f}, Same: {P_exp_same:.4f}"
    )
    print(
        f"Enrichment Ratios:        Convergent: {E_conv:.4f}, Divergent: {E_div:.4f}, Same: {E_same:.4f}"
    )
    print()

data_3bin = pl.DataFrame(rows_3bin)

# %%
# Composite figure layout
width = 15
violin_height = width / 2
bar_height = violin_height
dpi = 300

fig = plt.figure(figsize=(width, violin_height + bar_height), dpi=dpi)
gs = GridSpec(
    nrows=2,
    ncols=1,
    height_ratios=[violin_height, bar_height],
    hspace=0.20,
    figure=fig,
)
xlim = (0.5, len(groups) + 0.5)  # (0.5, 8.5)

# %%
# ==========
# Panel A: Δ violin plot
# ==========
axA = fig.add_subplot(gs[0, 0])

positions = list(range(1, len(groups) + 1))

vp = axA.violinplot(
    delta_violin_data,
    positions=positions,
    widths=0.85,
    showmeans=False,
    showmedians=False,
    showextrema=False,
)
for body in vp["bodies"]:
    body.set_facecolor(VIOLIN_COLOR)
    body.set_alpha(0.5)

axA.boxplot(
    delta_violin_data,
    positions=positions,
    widths=0.25,
    showfliers=False,
    medianprops=dict(linewidth=2, color="black"),
)
axA.axhline(0, linewidth=1, color="black", alpha=0.5, zorder=1)

axA.set_xticks(positions)
axA.set_xticklabels(
    [
        _tick_label(g, an, igr, {})
        for g, an, igr in zip(groups, an_by_group, igr_by_group)
    ],
    rotation=0,
    fontsize=11,
)
axA.tick_params(axis="both", labelsize=13)
axA.set_ylabel(
    r"Within-genome $\Delta$ median $\log_{10}$ IGR length" "\n" r"(opposite $-$ same)",
    fontsize=13,
)
axA.set_xlim(xlim)
axA.grid(axis="y", alpha=0.2)

axA.axvline(5.5, color="gray", linestyle="--", alpha=0.3, linewidth=1.5)
fig.text(0.125, 0.898, "A", fontsize=16, fontweight="bold", va="top")

# %%
# ==========
# Panel B: Bar plot of enrichment ratios for convergent, divergent, and same-polarity IGRs
# ==========
axB = fig.add_subplot(gs[1, 0])

positions = list(range(1, len(groups) + 1))
bar_width = 0.25

axB.bar(
    [p - bar_width for p in positions],
    data_3bin["E_conv"],
    bar_width,
    label="Convergent",
    color=COLOR_CONV,
    zorder=3,
)
axB.bar(
    positions,
    data_3bin["E_div"],
    bar_width,
    label="Divergent",
    color=COLOR_DIV,
    zorder=3,
)
axB.bar(
    [p + bar_width for p in positions],
    data_3bin["E_same"],
    bar_width,
    label="Same",
    color=COLOR_SAME,
    zorder=3,
)

axB.axhline(1, linewidth=1, color="black", alpha=0.5, zorder=1)

axB.set_xticks(positions)
axB.set_xticklabels(
    [group_label1[g].replace(" (", "\n(") for g in data_3bin["group"]],
    fontsize=10,
)
axB.tick_params(axis="both", labelsize=13)
axB.set_ylabel("Intergenic nucleotide occupancy ratio (E)", fontsize=13)
axB.set_ylim(
    0,
    max([*data_3bin["E_conv"], *data_3bin["E_div"], *data_3bin["E_same"]]) * 1.10,
)
axB.set_axisbelow(True)
axB.set_xlim(xlim)
axB.grid(axis="y", alpha=0.2)

axB.axvline(5.5, color="gray", linestyle="--", alpha=0.3, linewidth=1.5)

legend_elements = [
    mpatches.Patch(color=COLOR_SAME, label="Same-polarity"),
    mpatches.Patch(color=COLOR_CONV, label="Convergent"),
    mpatches.Patch(color=COLOR_DIV, label="Divergent"),
    plt.Line2D([0], [0], color="black", linestyle="--", linewidth=1.2, label="E = 1"),
]
axB.legend(handles=legend_elements, fontsize=10)
mit_positions = positions[:5]
plt_positions = positions[5:]
for xc, label in [
    (mean(mit_positions), "Mitochondria"),
    (mean(plt_positions), "Plastids"),
]:
    axB.text(
        xc,
        -0.10,
        label,
        ha="center",
        va="top",
        fontweight="bold",
        fontsize=15,
        transform=axB.get_xaxis_transform(),
    )
fig.text(0.125, 0.478, "B", fontsize=16, fontweight="bold", va="top")

# %%
out_path = CWD / "figure1.png"
fig.savefig(out_path, dpi=300, bbox_inches="tight")
print(f"Saved composite figure to: {out_path}")
